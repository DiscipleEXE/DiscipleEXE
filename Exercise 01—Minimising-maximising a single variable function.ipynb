# %% [markdown]
# <a href="https://colab.research.google.com/github/DiscipleEXE/DiscipleEXE/blob/main/Exercise%2001%E2%80%94Minimising-maximising%20a%20single%20variable%20function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Create a python function that implements $z(x)=sin(x^2)$:

# %% [markdown]
# <img src="https://github.com/nmarincic/machineintelligence/blob/master/img/sin(x2)-2.png?raw=1" alt="drawing" width="1000"/>

# %%
import math
def z(x):
  print(math.sin(x ** 2))

# %% [markdown]
# Evaluate the function $z(x)$ for different values of $x$:

# %% [markdown]
# Create a python function that implements $\frac{dz}{dx}=cos(x^2)2x$:

# %% [markdown]
# <img src="https://github.com/nmarincic/machineintelligence/blob/master/img/cos(x2)2x-2.png?raw=1" alt="drawing" width="1000"/>

# %%
def derivative_zx(x):
  print(math.cos(x**2) * 2 * x)

# %% [markdown]
# Evaluate the function $\frac{dz}{dx}$ for different values of $x$:

# %%
derivative_zx(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_664/101958588.py in <cell line: 0>()
# ----> 1 derivative_zx(1)
#
# TypeError: 'int' object is not callable

# %% [markdown]
# Introduce a variable `x_old` that stores numbers, and pass these values to both functions:

# %% [markdown]
# #### Excercise 1:

# %% [markdown]
# If we are at the point `x_old = 1.5` and wish to minimise our function $z(x)$, write a code that computes the new value of x, `x_new` which if takens as an input to $z(x)$ will __decrease__ it.

# %% [markdown]
# <img src="https://github.com/nmarincic/machineintelligence/blob/master/img/functions_at_1.5.png?raw=1" alt="drawing" width="1000"/>

# %% [markdown]
# Should we move $x$ to the left or to the right on the graph?

# %% [markdown]
# _______

# %% [markdown]
# #### Excercise 2:

# %% [markdown]
# If we are at the point `x_old = -0.5` and wish to __maximise__ our function $z(x)$, write a code that computes the new value of x, `x_new` which if takens as an input to $z(x)$ will __increase__ it.

# %% [markdown]
# <img src="https://github.com/nmarincic/machineintelligence/blob/master/img/functions_at_-0.5.png?raw=1" alt="drawing" width="1000"/>

# %% [markdown]
# Should we move $x$ to the left or to the right on the graph?

# %% [markdown]
# ___________
